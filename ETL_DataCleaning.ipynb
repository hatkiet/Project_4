# %%
import pandas as pd
# Out:
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.

# %%
df = pd.read_csv("financialdata.csv")
df.head()
# Out:
#            id    items ticker competitor  total_receivables  total_assets  \
# 0  DELLQ32023  Q3 2023   DELL       AAPL            16346.0         85172
# 1  DELLQ42023  Q4 2023   DELL       AAPL            17763.0         89611
# 2  DELLQ12024  Q1 2024   DELL       AAPL            14412.0         84094
# 3  DELLQ22024  Q2 2024   DELL       AAPL            15158.0         85658
# 4  DELLQ32024  Q3 2024   DELL       AAPL            14260.0         83264
#
#    cash_and_short_term_inv  total_liabilities  total_debt  total_equity  ...  \
# 0                   4909.0              88641       27329         -3469  ...
# 1                   8607.0              92733       29588         -3122  ...
# 2                   7631.0              87117       28432         -3023  ...
# 3                   8364.0              88430       27138         -2772  ...
# 4                   8298.0              85928       26617         -2664  ...
#
# ...

# %%
df.count()
# Out:
# id                              25090
# items                           25090
# ticker                          25090
# competitor                      25090
# total_receivables               21519
# total_assets                    25090
# cash_and_short_term_inv         21873
# total_liabilities               25090
# total_debt                      25090
# total_equity                    25090
# cost_of_revenue                 20156
# gross_profit                    20156
# operating_income                23988
# interest_expense                23988
# interest_coverage               23985
# total_cost_of_revenue           15307
# total_inventory                 15306
# inventory_turnover              15305
# total_revenue                   24864
# net_income                      24864
# quick_assets                    21527
# tot_curr_assets                 22089
# total_current_liab              22089
# accounts_receivable_turnover    21484
# avg_collection_period           21519
# ...

# %%
df[:2]
# Out:
#            id    items ticker competitor  total_receivables  total_assets  \
# 0  DELLQ32023  Q3 2023   DELL       AAPL            16346.0         85172
# 1  DELLQ42023  Q4 2023   DELL       AAPL            17763.0         89611
#
#    cash_and_short_term_inv  total_liabilities  total_debt  total_equity  ...  \
# 0                   4909.0              88641       27329         -3469  ...
# 1                   8607.0              92733       29588         -3122  ...
#
#    debt_to_equity  equity_ratio  gross_profit_margin  net_inc_margin  \
# 0       -7.878063    -24.552321             0.230856        0.009911
# 1       -9.477258    -28.703075             0.229881        0.024522
#
#    quick_ratio  return_on_assets  return_on_equity  operating_margin  \
# 0     0.408695          0.002877         -0.070626          0.030824
# 1     0.510512          0.006852         -0.196669          0.051719
#
#    working_capital  working_cap_turnover
# 0         -13220.0             -1.869970
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 25090 entries, 0 to 25089
# Data columns (total 40 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   id                            25090 non-null  object
#  1   items                         25090 non-null  object
#  2   ticker                        25090 non-null  object
#  3   competitor                    25090 non-null  object
#  4   total_receivables             21519 non-null  float64
#  5   total_assets                  25090 non-null  int64
#  6   cash_and_short_term_inv       21873 non-null  float64
#  7   total_liabilities             25090 non-null  int64
#  8   total_debt                    25090 non-null  int64
#  9   total_equity                  25090 non-null  int64
#  10  cost_of_revenue               20156 non-null  float64
#  11  gross_profit                  20156 non-null  float64
# ...

# %%
df.ticker.value_counts()
# Out:
# ticker
# NEE     102
# ABT      90
# RMD      84
# ETR      79
# EIX      79
#        ...
# RSI       5
# HTOO      3
# FIHL      3
# HG        3
# MRT       2
# Name: count, Length: 1262, dtype: int64

# %%
df[df.ticker == "NEE"]
# Out:
#               id    items ticker competitor  total_receivables  total_assets  \
# 12042  NEEQ42022  Q4 2022    NEE        EIX             5093.0        158935
# 12053  NEEQ12023  Q1 2023    NEE        LNT             3932.0        165357
# 12065  NEEQ42023  Q4 2023    NEE        NRG             6040.0        177489
# 12071  NEEQ12023  Q1 2023    NEE        PNW             3932.0        165357
# 12085  NEEQ12024  Q1 2024    NEE        AEP             5195.0        179950
# ...          ...      ...    ...        ...                ...           ...
# 18001  NEEQ12023  Q1 2023    NEE        XEL             3932.0        165357
# 18014  NEEQ12024  Q1 2024    NEE        NEE             5195.0        179950
# 18025  NEEQ22023  Q2 2023    NEE        AEP             4594.0        168275
# 18049  NEEQ12023  Q1 2023    NEE        ETR             3932.0        165357
# 18079  NEEQ12024  Q1 2024    NEE       EVRG             5195.0        179950
#
# ...

# %%
df.ticker
# Out:
# 0        DELL
# 1        DELL
# 2        DELL
# 3        DELL
# 4        DELL
#          ...
# 25085     MEG
# 25086     DRI
# 25087    IDXX
# 25088    DXCM
# 25089     ZTS
# Name: ticker, Length: 25090, dtype: object

# %%
df['items'].sort_values()
# Out:
# 13929    Q1 2001
# 13880    Q1 2001
# 13930    Q1 2002
# 16669    Q1 2002
# 1157     Q1 2002
#           ...
# 9651     Q4 2024
# 22765    Q4 2024
# 6115     Q4 2024
# 22648    Q4 2024
# 23749    Q4 2024
# Name: items, Length: 25090, dtype: object

# %%
qtrs = list(df['items'].replace('.*\s','',regex=True) +" "+ df['items'].replace('\s.*','',regex=True))

# %%
df.insert(0,'Qtr', qtrs)

# %%
df.sort_values('Qtr',inplace=True)

# %%
df.id.value_counts()
# Out:
# id
# NEEQ42023       17
# NEEQ22023       17
# NEEQ42022       17
# NEEQ12024       17
# NEEQ32023       17
#                 ..
# MASIQ42023       1
# EACOQ22023       1
# AVTQ22023        1
# BRQ42023         1
# CAVAQ12024.1     1
# Name: count, Length: 7230, dtype: int64

# %%
df.drop(['items', 'id'], axis=1, inplace=True)

# %%
df[:2]
# Out:
#            Qtr ticker competitor  total_receivables  total_assets  \
# 13929  2001 Q1   FINN        CMA                NaN          9489
# 13880  2001 Q1   FINN        KEY                NaN          9489
#
#        cash_and_short_term_inv  total_liabilities  total_debt  total_equity  \
# 13929                      NaN               8725         339           764
# 13880                      NaN               8725         339           764
#
#        cost_of_revenue  ...  debt_to_equity  equity_ratio  \
# 13929              NaN  ...        0.443717     12.420157
# 13880              NaN  ...        0.443717     12.420157
#
#        gross_profit_margin  net_inc_margin  quick_ratio  return_on_assets  \
# 13929                  NaN        0.153235          NaN           1.72505
# 13880                  NaN        0.153235          NaN           1.72505
#
#        return_on_equity  operating_margin  working_capital  \
# 13929         21.425393          0.153235              NaN
# ...

# %%
df.count()
# Out:
# Qtr                             25090
# ticker                          25090
# competitor                      25090
# total_receivables               21519
# total_assets                    25090
# cash_and_short_term_inv         21873
# total_liabilities               25090
# total_debt                      25090
# total_equity                    25090
# cost_of_revenue                 20156
# gross_profit                    20156
# operating_income                23988
# interest_expense                23988
# interest_coverage               23985
# total_cost_of_revenue           15307
# total_inventory                 15306
# inventory_turnover              15305
# total_revenue                   24864
# net_income                      24864
# quick_assets                    21527
# tot_curr_assets                 22089
# total_current_liab              22089
# accounts_receivable_turnover    21484
# avg_collection_period           21519
# assets_turnover                 24858
# ...

# %%
df.dropna().count()
# Out:
# Qtr                             14837
# ticker                          14837
# competitor                      14837
# total_receivables               14837
# total_assets                    14837
# cash_and_short_term_inv         14837
# total_liabilities               14837
# total_debt                      14837
# total_equity                    14837
# cost_of_revenue                 14837
# gross_profit                    14837
# operating_income                14837
# interest_expense                14837
# interest_coverage               14837
# total_cost_of_revenue           14837
# total_inventory                 14837
# inventory_turnover              14837
# total_revenue                   14837
# net_income                      14837
# quick_assets                    14837
# tot_curr_assets                 14837
# total_current_liab              14837
# accounts_receivable_turnover    14837
# avg_collection_period           14837
# assets_turnover                 14837
# ...

# %%
for col in df.columns:
    if '' in col:
        print(col)
