# %%
# Libraries and Dependencies
# for data manipulation and numerical operations
import pandas as pd
import numpy as np
import warnings
warnings.simplefilter(action='ignore')

# for data visualisation
import matplotlib.pyplot as plt
import seaborn as sns
sns.set_style('whitegrid')
plt.style.use("fivethirtyeight")
# %matplotlib inline

from pathlib import Path
import missingno as msno

import hvplot.pandas
from sklearn.cluster import KMeans
from sklearn.decomposition import PCA
from sklearn.preprocessing import StandardScaler

from datetime import datetime
# Out:
# <style>*[data-root-id],
# *[data-root-id] > * {
#   box-sizing: border-box;
#   font-family: var(--jp-ui-font-family);
#   font-size: var(--jp-ui-font-size1);
#   color: var(--vscode-editor-foreground, var(--jp-ui-font-color1));
# }
#
# /* Override VSCode background color */
# .cell-output-ipywidget-background:has(
#     > .cell-output-ipywidget-background > .lm-Widget > *[data-root-id]
#   ),
# .cell-output-ipywidget-background:has(> .lm-Widget > *[data-root-id]) {
#   background-color: transparent !important;
# }
# </style>

# %%
# # Store filepath in a variable
file = Path("finance_data.csv")

# %%
# Read the raw data with the Pandas library
raw_df = pd.read_csv(file)
raw_df.head(20)
# Out:
#             id    items ticker competitor  total_receivables  total_assets  \
# 0   DELLQ32023  Q3 2023   DELL       AAPL            16346.0         85172
# 1   DELLQ42023  Q4 2023   DELL       AAPL            17763.0         89611
# 2   DELLQ12024  Q1 2024   DELL       AAPL            14412.0         84094
# 3   DELLQ22024  Q2 2024   DELL       AAPL            15158.0         85658
# 4   DELLQ32024  Q3 2024   DELL       AAPL            14260.0         83264
# 5    HPEQ42022  Q4 2022    HPE       AAPL             7623.0         57123
# 6    HPEQ12023  Q1 2023    HPE       AAPL             7927.0         55591
# 7    HPEQ22023  Q2 2023    HPE       AAPL             7427.0         55549
# 8    HPEQ32023  Q3 2023    HPE       AAPL             7166.0         56415
# 9    HPEQ42023  Q4 2023    HPE       AAPL             7024.0         57153
# 10  PSTGQ32023  Q3 2023   PSTG       AAPL              436.0          3253
# 11  PSTGQ42023  Q4 2023   PSTG       AAPL              612.0          3543
# 12  PSTGQ12024  Q1 2024   PSTG       AAPL              391.0          2959
# 13  PSTGQ22024  Q2 2024   PSTG       AAPL              525.0          3134
# 14  PSTGQ32024  Q3 2024   PSTG       AAPL              636.0          3356
# 15   WDCQ22023  Q2 2023    WDC       AAPL             1905.0         25047
# 16   WDCQ32023  Q3 2023    WDC       AAPL             1591.0         25151
# 17   WDCQ42023  Q4 2023    WDC       AAPL             1598.0         24546
# 18   WDCQ12024  Q1 2024    WDC       AAPL             1451.0         24001
# 19   WDCQ22024  Q2 2024    WDC       AAPL             1523.0         24385
#
#     cash_and_short_term_inv  total_liabilities  total_debt  total_equity  ...  \
# 0                    4909.0              88641       27329         -3469  ...
# 1                    8607.0              92733       29588         -3122  ...
# 2                    7631.0              87117       28432         -3023  ...
# 3                    8364.0              88430       27138         -2772  ...
# 4                    8298.0              85928       26617         -2664  ...
# 5                    4163.0              37259       12465         19864  ...
# 6                    2530.0              35580       12926         20011  ...
# 7                    2781.0              35183       13376         20366  ...
# 8                    2919.0              35793       13352         20622  ...
# 9                    4270.0              35971       12355         21182  ...
# 10                   1465.0               2412         585           841  ...
# 11                   1582.0               2602         585           941  ...
# 12                   1184.0               2053         110           906  ...
# 13                   1229.0               2148         110           986  ...
# 14                   1351.0               2207         106          1148  ...
# 15                   1871.0              12932        7071         12115  ...
# 16                   2220.0              12664        7073         12487  ...
# 17                   2023.0              12706        7070         11840  ...
# 18                   2032.0              13012        7672         10989  ...
# 19                   2481.0              13441        8393         10944  ...
#
#     debt_to_equity  gross_profit_margin  net_inc_margin  quick_ratio  \
# 0        -7.878063             0.230856        0.009911     0.408695
# 1        -9.477258             0.229881        0.024522     0.510512
# 2        -9.405227             0.239843        0.027865     0.470753
# 3        -9.790043             0.234891        0.020145     0.461741
# 4        -9.991366             0.231360        0.045211     0.461526
# 5         0.627517             0.329437       -0.038623     0.508587
# 6         0.645945             0.340376        0.064157     0.486916
# 7         0.656781             0.360247        0.059946     0.504074
# 8         0.647464             0.358469        0.066267     0.500000
# 9         0.583278             0.348116        0.087335     0.516132
# 10        0.695600             0.689349       -0.001479     1.171288
# 11        0.621679             0.692593        0.091358     1.253714
# 12        0.121413             0.701188       -0.113752     1.424051
# 13        0.111562             0.706821       -0.010160     1.456811
# 14        0.092334             0.724771        0.091743     1.605008
# 15        0.583657             0.169939       -0.145156     0.861707
# 16        0.566429             0.102034       -0.204067     0.724387
# 17        0.597128             0.034431       -0.267590     0.666360
# 18        0.698153             0.036000       -0.249091     0.601347
# 19        0.766904             0.162269       -0.094657     0.853186
#
#     return_on_assets  return_on_equity  operating_margin  working_capital  \
# 0           0.002877         -0.070626          0.030824         -13220.0
# 1           0.006852         -0.196669          0.051719          -9303.0
# 2           0.006933         -0.192855          0.051095          -9433.0
# 3           0.005394         -0.166667          0.050798         -11943.0
# 4           0.012082         -0.377628          0.066784         -11890.0
# 5          -0.005322         -0.015304         -0.045610          -2668.0
# 6           0.009012          0.025036          0.075554          -3242.0
# 7           0.007525          0.020524          0.075434          -2691.0
# 8           0.008225          0.022500          0.073693          -2515.0
# 9           0.011233          0.030309          0.069650          -2934.0
# 10         -0.000307         -0.001189          0.013314            586.0
# 11          0.020886          0.078640          0.080247            725.0
# 12         -0.022643         -0.073951         -0.122241            762.0
# 13         -0.002234         -0.007099         -0.008708            837.0
# 14          0.020858          0.060976          0.096986           1009.0
# 15         -0.018006         -0.037227         -0.103315           3999.0
# 16         -0.022743         -0.045808         -0.168391           3222.0
# 17         -0.029129         -0.060389         -0.243263           2452.0
# 18         -0.028540         -0.062335         -0.216727           1785.0
# 19         -0.011770         -0.026224         -0.069261           3145.0
#
#     working_cap_turnover  equity_ratio
# 0              -1.869970     -0.040729
# 1              -2.691497     -0.034839
# 2              -2.217958     -0.035948
# 3              -1.920288     -0.032361
# 4              -1.871405     -0.031995
# 5              -2.950150      0.347741
# 6              -2.408698      0.359968
# 7              -2.591230      0.366631
# 8              -2.784095      0.365541
# 9              -2.505453      0.370619
# 10              1.153584      0.258531
# 11              1.117241      0.265594
# 12              0.772966      0.306185
# 13              0.823178      0.314614
# 14              0.756194      0.342074
# 15              0.776944      0.483691
# 16              0.869957      0.496481
# 17              1.089723      0.482360
# 18              1.540616      0.457856
# 19              0.964070      0.448800
#
# [20 rows x 40 columns]

# %%
# Print out columns names
raw_df.columns
# Out:
# Index(['id', 'items', 'ticker', 'competitor', 'total_receivables',
#        'total_assets', 'cash_and_short_term_inv', 'total_liabilities',
#        'total_debt', 'total_equity', 'cost_of_revenue', 'gross_profit',
#        'operating_income', 'interest_expense', 'interest_coverage',
#        'total_cost_of_revenue', 'total_inventory', 'inventory_turnover',
#        'total_revenue', 'net_income', 'quick_assets', 'tot_curr_assets',
#        'total_current_liab', 'accounts_receivable_turnover',
#        'avg_collection_period', 'assets_turnover', 'basic_earning_power',
#        'cash_ratio', 'current_ratio', 'debt_ratio', 'debt_to_equity',
#        'gross_profit_margin', 'net_inc_margin', 'quick_ratio',
#        'return_on_assets', 'return_on_equity', 'operating_margin',
#        'working_capital', 'working_cap_turnover', 'equity_ratio'],
#       dtype='object')

# %%
raw_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 25090 entries, 0 to 25089
# Data columns (total 40 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   id                            25090 non-null  object
#  1   items                         25090 non-null  object
#  2   ticker                        25090 non-null  object
#  3   competitor                    25090 non-null  object
#  4   total_receivables             21519 non-null  float64
#  5   total_assets                  25090 non-null  int64
#  6   cash_and_short_term_inv       21873 non-null  float64
#  7   total_liabilities             25090 non-null  int64
#  8   total_debt                    25090 non-null  int64
#  9   total_equity                  25090 non-null  int64
#  10  cost_of_revenue               20156 non-null  float64
#  11  gross_profit                  20156 non-null  float64
#  12  operating_income              23988 non-null  float64
#  13  interest_expense              23988 non-null  float64
#  14  interest_coverage             23985 non-null  float64
#  15  total_cost_of_revenue         15307 non-null  float64
#  16  total_inventory               15306 non-null  float64
#  17  inventory_turnover            15305 non-null  float64
#  18  total_revenue                 24864 non-null  float64
#  19  net_income                    24864 non-null  float64
#  20  quick_assets                  21527 non-null  float64
#  21  tot_curr_assets               22089 non-null  float64
#  22  total_current_liab            22089 non-null  float64
#  23  accounts_receivable_turnover  21484 non-null  float64
#  24  avg_collection_period         21519 non-null  float64
#  25  assets_turnover               24858 non-null  float64
#  26  basic_earning_power           23988 non-null  float64
#  27  cash_ratio                    21871 non-null  float64
#  28  current_ratio                 20080 non-null  float64
#  29  debt_ratio                    25090 non-null  float64
#  30  debt_to_equity                25080 non-null  float64
#  31  gross_profit_margin           20140 non-null  float64
#  32  net_inc_margin                24864 non-null  float64
#  33  quick_ratio                   21527 non-null  float64
#  34  return_on_assets              24864 non-null  float64
#  35  return_on_equity              24864 non-null  float64
#  36  operating_margin              23988 non-null  float64
#  37  working_capital               22089 non-null  float64
#  38  working_cap_turnover          22089 non-null  float64
#  39  equity_ratio                  25090 non-null  float64
# dtypes: float64(32), int64(4), object(4)
# memory usage: 7.7+ MB

# %%
# Plot the dataset
msno.matrix(raw_df)
# Out:
# <Axes: >

# %%
# Finding NAN values
nan_values = raw_df.isna().sum().sort_values(ascending=False)
nan_values_percentage = (nan_values/raw_df.shape[0])*100

# Output the DataFrame with two columns nan_values and nan_values_percentage
pd.concat([nan_values, nan_values_percentage], axis=1).rename(columns= {0:"NaN Values", 1:"(%) of NaN Values"}).round(2)
# Out:
#                               NaN Values  (%) of NaN Values
# inventory_turnover                  9785              39.00
# total_inventory                     9784              39.00
# total_cost_of_revenue               9783              38.99
# current_ratio                       5010              19.97
# gross_profit_margin                 4950              19.73
# cost_of_revenue                     4934              19.67
# gross_profit                        4934              19.67
# accounts_receivable_turnover        3606              14.37
# avg_collection_period               3571              14.23
# total_receivables                   3571              14.23
# quick_assets                        3563              14.20
# quick_ratio                         3563              14.20
# cash_ratio                          3219              12.83
# cash_and_short_term_inv             3217              12.82
# working_cap_turnover                3001              11.96
# total_current_liab                  3001              11.96
# tot_curr_assets                     3001              11.96
# working_capital                     3001              11.96
# interest_coverage                   1105               4.40
# interest_expense                    1102               4.39
# operating_income                    1102               4.39
# basic_earning_power                 1102               4.39
# operating_margin                    1102               4.39
# assets_turnover                      232               0.92
# total_revenue                        226               0.90
# net_income                           226               0.90
# net_inc_margin                       226               0.90
# return_on_assets                     226               0.90
# return_on_equity                     226               0.90
# debt_to_equity                        10               0.04
# id                                     0               0.00
# debt_ratio                             0               0.00
# items                                  0               0.00
# total_equity                           0               0.00
# total_debt                             0               0.00
# total_liabilities                      0               0.00
# total_assets                           0               0.00
# competitor                             0               0.00
# ticker                                 0               0.00
# equity_ratio                           0               0.00

# %%
# Or check NULL values
raw_df.isnull().sum().sort_values(ascending=False)
# Out:
# inventory_turnover              9785
# total_inventory                 9784
# total_cost_of_revenue           9783
# current_ratio                   5010
# gross_profit_margin             4950
# cost_of_revenue                 4934
# gross_profit                    4934
# accounts_receivable_turnover    3606
# avg_collection_period           3571
# total_receivables               3571
# quick_assets                    3563
# quick_ratio                     3563
# cash_ratio                      3219
# cash_and_short_term_inv         3217
# working_cap_turnover            3001
# total_current_liab              3001
# tot_curr_assets                 3001
# working_capital                 3001
# interest_coverage               1105
# interest_expense                1102
# operating_income                1102
# basic_earning_power             1102
# operating_margin                1102
# assets_turnover                  232
# total_revenue                    226
# net_income                       226
# net_inc_margin                   226
# return_on_assets                 226
# return_on_equity                 226
# debt_to_equity                    10
# id                                 0
# debt_ratio                         0
# items                              0
# total_equity                       0
# total_debt                         0
# total_liabilities                  0
# total_assets                       0
# competitor                         0
# ticker                             0
# equity_ratio                       0
# dtype: int64

# %%
# Check and Drop duplicate rows based on all columns
raw_df = raw_df.drop_duplicates()

# Print the DataFrame to see the changes
raw_df
# Out:
#                id    items ticker competitor  total_receivables  total_assets  \
# 0      DELLQ32023  Q3 2023   DELL       AAPL            16346.0         85172
# 1      DELLQ42023  Q4 2023   DELL       AAPL            17763.0         89611
# 2      DELLQ12024  Q1 2024   DELL       AAPL            14412.0         84094
# 3      DELLQ22024  Q2 2024   DELL       AAPL            15158.0         85658
# 4      DELLQ32024  Q3 2024   DELL       AAPL            14260.0         83264
# ...           ...      ...    ...        ...                ...           ...
# 25085   MEGQ42023  Q4 2023    MEG         WM              164.0           817
# 25086   DRIQ32024  Q3 2024    DRI        YUM               72.0         11358
# 25087  IDXXQ12024  Q1 2024   IDXX        ZBH              578.0          3354
# 25088  DXCMQ12024  Q1 2024   DXCM        ZBH              985.0          6482
# 25089   ZTSQ12024  Q1 2024    ZTS        ZTS             1293.0         14348
#
#        cash_and_short_term_inv  total_liabilities  total_debt  total_equity  \
# 0                       4909.0              88641       27329         -3469
# 1                       8607.0              92733       29588         -3122
# 2                       7631.0              87117       28432         -3023
# 3                       8364.0              88430       27138         -2772
# 4                       8298.0              85928       26617         -2664
# ...                        ...                ...         ...           ...
# 25085                     23.0                343         175           474
# 25086                    244.0               9177        2840          2181
# 25087                    397.0               1785         946          1569
# 25088                   2897.0               4235        2494          2247
# 25089                   1973.0               9290        6586          5058
#
#        ...  debt_to_equity  gross_profit_margin  net_inc_margin  quick_ratio  \
# 0      ...       -7.878063             0.230856        0.009911     0.408695
# 1      ...       -9.477258             0.229881        0.024522     0.510512
# 2      ...       -9.405227             0.239843        0.027865     0.470753
# 3      ...       -9.790043             0.234891        0.020145     0.461741
# 4      ...       -9.991366             0.231360        0.045211     0.461526
# ...    ...             ...                  ...             ...          ...
# 25085  ...        0.369198             0.385074       -0.008694     1.484127
# 25086  ...        1.302155             0.217143        0.105210     0.139085
# 25087  ...        0.602932             0.615145        0.244813     1.018809
# 25088  ...        1.109924             0.610206        0.158523     2.435383
# 25089  ...        1.302096             0.707763        0.273516     1.710843
#
#        return_on_assets  return_on_equity  operating_margin  working_capital  \
# 0              0.002877         -0.070626          0.030824         -13220.0
# 1              0.006852         -0.196669          0.051719          -9303.0
# 2              0.006933         -0.192855          0.051095          -9433.0
# 3              0.005394         -0.166667          0.050798         -11943.0
# 4              0.012082         -0.377628          0.066784         -11890.0
# ...                 ...               ...               ...              ...
# 25085         -1.763770         -3.040084         -0.053764             75.0
# 25086          0.027558          0.143512          0.130084          -1396.0
# 25087          0.070364          0.150414          0.310166            545.0
# 25088          0.022524          0.064976          0.109663           3027.0
# 25089          0.041748          0.118426          0.341096           4450.0
#
#        working_cap_turnover  equity_ratio
# 0                 -1.869970     -0.040729
# 1                 -2.691497     -0.034839
# 2                 -2.217958     -0.035948
# 3                 -1.920288     -0.032361
# 4                 -1.871405     -0.031995
# ...                     ...           ...
# 25085           2209.893333      0.580171
# 25086             -2.131089      0.192023
# 25087              1.768807      0.467800
# 25088              0.304262      0.346652
# 25089              0.492135      0.352523
#
# [25090 rows x 40 columns]

# %%
# Statistical analysis for categorical data in dataset
raw_df.describe(include='O')
# Out:
#                id    items ticker competitor
# count       25090    25090  25090      25090
# unique       7230       77   1262        500
# top     NEEQ32023  Q4 2023    NEE        EIX
# freq           17     4276    102         67

# %%
# Statistical analysis for numerical data in dataset
raw_df.describe()
# Out:
#        total_receivables  total_assets  cash_and_short_term_inv  \
# count       21519.000000  2.509000e+04             21873.000000
# mean         3897.776941  7.148198e+04              4567.648516
# std         11806.502246  2.675111e+05             19639.307281
# min             0.000000  0.000000e+00                 0.000000
# 25%           421.500000  5.453000e+03               229.000000
# 50%          1006.000000  1.529200e+04               698.000000
# 75%          2724.500000  5.074100e+04              2295.000000
# max        222269.000000  4.090727e+06            504108.000000
#
#        total_liabilities    total_debt   total_equity  cost_of_revenue  \
# count       2.509000e+04  2.509000e+04   25090.000000     2.015600e+04
# mean        5.486882e+04  1.642880e+04   16613.171582     2.150689e+04
# std         2.419217e+05  6.067189e+04   40227.141076     6.026832e+04
# min        -1.101900e+04  0.000000e+00 -100641.000000    -8.218000e+03
# 25%         3.049000e+03  1.231000e+03    1540.250000     5.880000e+02
# 50%         8.986000e+03  4.104000e+03    4886.000000     1.604000e+03
# 75%         3.329850e+04  1.286500e+04   14725.000000     5.583000e+03
# max         3.754090e+06  1.101976e+06  432301.000000     1.000100e+06
#
#         gross_profit  operating_income  interest_expense  ...  debt_to_equity  \
# count   20156.000000      23988.000000      23988.000000  ...    2.508000e+04
# mean    22013.409506       5144.069118       2485.997582  ...             inf
# std     61563.994265      30823.092165       9644.774944  ...             NaN
# min    -33100.000000    -525417.000000        -25.000000  ...   -1.484500e+03
# 25%       542.000000        117.000000         24.000000  ...    2.808981e-01
# 50%      1282.000000        365.000000         76.000000  ...    6.693202e-01
# 75%      4138.500000       1216.500000        300.000000  ...    1.421242e+00
# max    926084.000000     396503.000000     279765.000000  ...             inf
#
#        gross_profit_margin  net_inc_margin   quick_ratio  return_on_assets  \
# count         20140.000000    2.486400e+04  2.152700e+04      2.486400e+04
# mean              0.464170             NaN           inf               NaN
# std               0.271736             NaN           NaN               NaN
# min              -6.060606            -inf  0.000000e+00              -inf
# 25%               0.298958    3.026007e-02  5.727282e-01      3.233169e-03
# 50%               0.446809    9.886617e-02  9.612418e-01      1.355990e-02
# 75%               0.646274    1.818182e-01  1.647335e+00      3.220951e-02
# max               2.128226             inf           inf               inf
#
#        return_on_equity  operating_margin  working_capital  \
# count      2.486400e+04      2.398800e+04     22089.000000
# mean               -inf               NaN      3451.481235
# std                 NaN               NaN     20371.036448
# min                -inf              -inf   -126538.000000
# 25%        1.161077e-02      5.724001e-02         1.000000
# 50%        3.698822e-02      1.429369e-01       521.000000
# 75%        8.331974e-02      2.384369e-01      1836.000000
# max        9.983222e+03               inf    452188.000000
#
#        working_cap_turnover  equity_ratio
# count          2.208900e+04  2.509000e+04
# mean           1.030595e+04          -inf
# std            5.841316e+04           NaN
# min           -3.620000e+05          -inf
# 25%            1.058846e-01  2.001640e-01
# 50%            1.219512e+00  3.521484e-01
# 75%            5.670040e+00  5.277660e-01
# max            1.799995e+06  1.111380e+00
#
# [8 rows x 36 columns]

# %%
# How many stock ID?
len(raw_df["ticker"].unique())
# Out:
# 1262

# %%
raw_df.ticker.value_counts()
# Out:
# ticker
# NEE     102
# ABT      90
# RMD      84
# ETR      79
# EIX      79
#        ...
# RSI       5
# HTOO      3
# FIHL      3
# HG        3
# MRT       2
# Name: count, Length: 1262, dtype: int64

# %%
# count plot for Stock ID "ticker"
plt.figure(figsize=(15,5))
sns.countplot(x=raw_df.ticker.value_counts())
plt.title('Count plot for - Stock ID' ,fontsize=15)
plt.xticks(rotation=0)
plt.show()

# %%
# Check only DELL
dell_df = raw_df[raw_df['ticker']=='DELL']
dell_df
# Out:
#                id    items ticker competitor  total_receivables  total_assets  \
# 0      DELLQ32023  Q3 2023   DELL       AAPL            16346.0         85172
# 1      DELLQ42023  Q4 2023   DELL       AAPL            17763.0         89611
# 2      DELLQ12024  Q1 2024   DELL       AAPL            14412.0         84094
# 3      DELLQ22024  Q2 2024   DELL       AAPL            15158.0         85658
# 4      DELLQ32024  Q3 2024   DELL       AAPL            14260.0         83264
# 2036   DELLQ12024  Q1 2024   DELL        HPQ            14412.0         84094
# 2037   DELLQ32024  Q3 2024   DELL        HPQ            14260.0         83264
# 2280   DELLQ12024  Q1 2024   DELL       NTAP            14412.0         84094
# 2591   DELLQ42023  Q4 2023   DELL        WDC            17763.0         89611
# 2592   DELLQ12024  Q1 2024   DELL        WDC            14412.0         84094
# 3669   DELLQ32024  Q3 2024   DELL        WDC            14260.0         83264
# 4579   DELLQ42023  Q4 2023   DELL       NTAP            17763.0         89611
# 4874   DELLQ32023  Q3 2023   DELL        WDC            16346.0         85172
# 5505   DELLQ22024  Q2 2024   DELL        HPQ            15158.0         85658
# 6050   DELLQ42024  Q4 2024   DELL       AAPL            13986.0         82089
# 6872   DELLQ32024  Q3 2024   DELL       NTAP            14260.0         83264
# 8064   DELLQ22024  Q2 2024   DELL       NTAP            15158.0         85658
# 9659   DELLQ42024  Q4 2024   DELL       NTAP            13986.0         82089
# 10752  DELLQ42024  Q4 2024   DELL        HPQ            13986.0         82089
# 11758  DELLQ22024  Q2 2024   DELL        WDC            15158.0         85658
# 16134  DELLQ42024  Q4 2024   DELL        WDC            13986.0         82089
# 19874  DELLQ32023  Q3 2023   DELL       NTAP            16346.0         85172
# 20805  DELLQ32023  Q3 2023   DELL        HPQ            16346.0         85172
# 21533  DELLQ42024  Q4 2024   DELL       SMCI            13986.0         82089
# 21995  DELLQ42023  Q4 2023   DELL        HPQ            17763.0         89611
#
#        cash_and_short_term_inv  total_liabilities  total_debt  total_equity  \
# 0                       4909.0              88641       27329         -3469
# 1                       8607.0              92733       29588         -3122
# 2                       7631.0              87117       28432         -3023
# 3                       8364.0              88430       27138         -2772
# 4                       8298.0              85928       26617         -2664
# 2036                    7631.0              87117       28432         -3023
# 2037                    8298.0              85928       26617         -2664
# 2280                    7631.0              87117       28432         -3023
# 2591                    8607.0              92733       29588         -3122
# 2592                    7631.0              87117       28432         -3023
# 3669                    8298.0              85928       26617         -2664
# 4579                    8607.0              92733       29588         -3122
# 4874                    4909.0              88641       27329         -3469
# 5505                    8364.0              88430       27138         -2772
# 6050                    7366.0              84493       25994         -2404
# 6872                    8298.0              85928       26617         -2664
# 8064                    8364.0              88430       27138         -2772
# 9659                    7366.0              84493       25994         -2404
# 10752                   7366.0              84493       25994         -2404
# 11758                   8364.0              88430       27138         -2772
# 16134                   7366.0              84493       25994         -2404
# 19874                   4909.0              88641       27329         -3469
# 20805                   4909.0              88641       27329         -3469
# 21533                   7366.0              84493       25994         -2404
# 21995                   8607.0              92733       29588         -3122
#
#        ...  debt_to_equity  gross_profit_margin  net_inc_margin  quick_ratio  \
# 0      ...       -7.878063             0.230856        0.009911     0.408695
# 1      ...       -9.477258             0.229881        0.024522     0.510512
# 2      ...       -9.405227             0.239843        0.027865     0.470753
# 3      ...       -9.790043             0.234891        0.020145     0.461741
# 4      ...       -9.991366             0.231360        0.045211     0.461526
# 2036   ...       -9.405227             0.239843        0.027865     0.470753
# 2037   ...       -9.991366             0.231360        0.045211     0.461526
# 2280   ...       -9.405227             0.239843        0.027865     0.470753
# 2591   ...       -9.477258             0.229881        0.024522     0.510512
# 2592   ...       -9.405227             0.239843        0.027865     0.470753
# 3669   ...       -9.991366             0.231360        0.045211     0.461526
# 4579   ...       -9.477258             0.229881        0.024522     0.510512
# 4874   ...       -7.878063             0.230856        0.009911     0.408695
# 5505   ...       -9.790043             0.234891        0.020145     0.461741
# 6050   ...      -10.812812             0.238193        0.051976     0.440302
# 6872   ...       -9.991366             0.231360        0.045211     0.461526
# 8064   ...       -9.790043             0.234891        0.020145     0.461741
# 9659   ...      -10.812812             0.238193        0.051976     0.440302
# 10752  ...      -10.812812             0.238193        0.051976     0.440302
# 11758  ...       -9.790043             0.234891        0.020145     0.461741
# 16134  ...      -10.812812             0.238193        0.051976     0.440302
# 19874  ...       -7.878063             0.230856        0.009911     0.408695
# 20805  ...       -7.878063             0.230856        0.009911     0.408695
# 21533  ...      -10.812812             0.238193        0.051976     0.440302
# 21995  ...       -9.477258             0.229881        0.024522     0.510512
#
#        return_on_assets  return_on_equity  operating_margin  working_capital  \
# 0              0.002877         -0.070626          0.030824         -13220.0
# 1              0.006852         -0.196669          0.051719          -9303.0
# 2              0.006933         -0.192855          0.051095          -9433.0
# 3              0.005394         -0.166667          0.050798         -11943.0
# 4              0.012082         -0.377628          0.066784         -11890.0
# 2036           0.006933         -0.192855          0.051095          -9433.0
# 2037           0.012082         -0.377628          0.066784         -11890.0
# 2280           0.006933         -0.192855          0.051095          -9433.0
# 2591           0.006852         -0.196669          0.051719          -9303.0
# 2592           0.006933         -0.192855          0.051095          -9433.0
# 3669           0.012082         -0.377628          0.066784         -11890.0
# 4579           0.006852         -0.196669          0.051719          -9303.0
# 4874           0.002877         -0.070626          0.030824         -13220.0
# 5505           0.005394         -0.166667          0.050798         -11943.0
# 6050           0.014131         -0.482529          0.069854         -12547.0
# 6872           0.012082         -0.377628          0.066784         -11890.0
# 8064           0.005394         -0.166667          0.050798         -11943.0
# 9659           0.014131         -0.482529          0.069854         -12547.0
# 10752          0.014131         -0.482529          0.069854         -12547.0
# 11758          0.005394         -0.166667          0.050798         -11943.0
# 16134          0.014131         -0.482529          0.069854         -12547.0
# 19874          0.002877         -0.070626          0.030824         -13220.0
# 20805          0.002877         -0.070626          0.030824         -13220.0
# 21533          0.014131         -0.482529          0.069854         -12547.0
# 21995          0.006852         -0.196669          0.051719          -9303.0
#
#        working_cap_turnover  equity_ratio
# 0                 -1.869970     -0.040729
# 1                 -2.691497     -0.034839
# 2                 -2.217958     -0.035948
# 3                 -1.920288     -0.032361
# 4                 -1.871405     -0.031995
# 2036              -2.217958     -0.035948
# 2037              -1.871405     -0.031995
# 2280              -2.217958     -0.035948
# 2591              -2.691497     -0.034839
# 2592              -2.217958     -0.035948
# 3669              -1.871405     -0.031995
# 4579              -2.691497     -0.034839
# 4874              -1.869970     -0.040729
# 5505              -1.920288     -0.032361
# 6050              -1.778752     -0.029285
# 6872              -1.871405     -0.031995
# 8064              -1.920288     -0.032361
# 9659              -1.778752     -0.029285
# 10752             -1.778752     -0.029285
# 11758             -1.920288     -0.032361
# 16134             -1.778752     -0.029285
# 19874             -1.869970     -0.040729
# 20805             -1.869970     -0.040729
# 21533             -1.778752     -0.029285
# 21995             -2.691497     -0.034839
#
# [25 rows x 40 columns]

# %%
# Check only NEE
nee_df = raw_df[raw_df['ticker']=='NEE']
nee_df
# Out:
#               id    items ticker competitor  total_receivables  total_assets  \
# 12042  NEEQ42022  Q4 2022    NEE        EIX             5093.0        158935
# 12053  NEEQ12023  Q1 2023    NEE        LNT             3932.0        165357
# 12065  NEEQ42023  Q4 2023    NEE        NRG             6040.0        177489
# 12071  NEEQ12023  Q1 2023    NEE        PNW             3932.0        165357
# 12085  NEEQ12024  Q1 2024    NEE        AEP             5195.0        179950
# ...          ...      ...    ...        ...                ...           ...
# 18001  NEEQ12023  Q1 2023    NEE        XEL             3932.0        165357
# 18014  NEEQ12024  Q1 2024    NEE        NEE             5195.0        179950
# 18025  NEEQ22023  Q2 2023    NEE        AEP             4594.0        168275
# 18049  NEEQ12023  Q1 2023    NEE        ETR             3932.0        165357
# 18079  NEEQ12024  Q1 2024    NEE       EVRG             5195.0        179950
#
#        cash_and_short_term_inv  total_liabilities  total_debt  total_equity  \
# 12042                   1601.0             119706       64966         39229
# 12053                   2275.0             122461       70641         42896
# 12065                   2690.0             130021       73211         47468
# 12071                   2275.0             122461       70641         42896
# 12085                   1642.0             131309       79937         48641
# ...                        ...                ...         ...           ...
# 18001                   2275.0             122461       70641         42896
# 18014                   1642.0             131309       79937         48641
# 18025                   1577.0             123482       72173         44793
# 18049                   2275.0             122461       70641         42896
# 18079                   1642.0             131309       79937         48641
#
#        ...  debt_to_equity  gross_profit_margin  net_inc_margin  quick_ratio  \
# 12042  ...        1.656071                  NaN        0.246918     0.250759
# 12053  ...        1.646797                  NaN        0.310602     0.244592
# 12065  ...        1.542323                  NaN        0.175923     0.312198
# 12071  ...        1.646797                  NaN        0.310602     0.244592
# 12085  ...        1.643408                  NaN        0.395742     0.275652
# ...    ...             ...                  ...             ...          ...
# 18001  ...        1.646797                  NaN        0.310602     0.244592
# 18014  ...        1.643408                  NaN        0.395742     0.275652
# 18025  ...        1.611256                  NaN        0.380324     0.248120
# 18049  ...        1.646797                  NaN        0.310602     0.244592
# 18079  ...        1.643408                  NaN        0.395742     0.275652
#
#        return_on_assets  return_on_equity  operating_margin  working_capital  \
# 12042          0.009576          0.038798          0.331927         -13205.0
# 12053          0.012615          0.048629          0.438058         -11828.0
# 12065          0.006817          0.025491          0.386740         -12602.0
# 12071          0.012615          0.048629          0.438058         -11828.0
# 12085          0.012604          0.046627          0.351248         -12123.0
# ...                 ...               ...               ...              ...
# 18001          0.012615          0.048629          0.438058         -11828.0
# 18014          0.012604          0.046627          0.351248         -12123.0
# 18025          0.016610          0.062398          0.380868         -11749.0
# 18049          0.012615          0.048629          0.438058         -11828.0
# 18079          0.012604          0.046627          0.351248         -12123.0
#
#        working_cap_turnover  equity_ratio
# 12042             -0.466793      0.246824
# 12053             -0.567805      0.259414
# 12065             -0.545786      0.267442
# 12071             -0.567805      0.259414
# 12085             -0.472738      0.270303
# ...                     ...           ...
# 18001             -0.567805      0.259414
# 18014             -0.472738      0.270303
# 18025             -0.625500      0.266189
# 18049             -0.567805      0.259414
# 18079             -0.472738      0.270303
#
# [102 rows x 40 columns]

# %%
nee_df.plot(kind='scatter', x="items", y="total_liabilities")
plt.tight_layout()
plt.show()

# %%
raw_df.columns
# Out:
# Index(['id', 'items', 'ticker', 'competitor', 'total_receivables',
#        'total_assets', 'cash_and_short_term_inv', 'total_liabilities',
#        'total_debt', 'total_equity', 'cost_of_revenue', 'gross_profit',
#        'operating_income', 'interest_expense', 'interest_coverage',
#        'total_cost_of_revenue', 'total_inventory', 'inventory_turnover',
#        'total_revenue', 'net_income', 'quick_assets', 'tot_curr_assets',
#        'total_current_liab', 'accounts_receivable_turnover',
#        'avg_collection_period', 'assets_turnover', 'basic_earning_power',
#        'cash_ratio', 'current_ratio', 'debt_ratio', 'debt_to_equity',
#        'gross_profit_margin', 'net_inc_margin', 'quick_ratio',
#        'return_on_assets', 'return_on_equity', 'operating_margin',
#        'working_capital', 'working_cap_turnover', 'equity_ratio'],
#       dtype='object')

# %%
liquidity_ratios_df = raw_df[['current_ratio', 'cash_ratio', 'quick_ratio', 'working_capital']]
solvency_ratios_df = raw_df[['debt_ratio', 'debt_to_equity','equity_ratio', 'interest_coverage']]
activity_ratios_df = raw_df[['working_cap_turnover', 'inventory_turnover', 'assets_turnover', 'accounts_receivable_turnover', 'avg_collection_period']]
profit_ratios_df = raw_df[['net_inc_margin', 'gross_profit_margin', 'operating_margin', 'return_on_assets', 'return_on_equity', 'basic_earning_power']]

# %%
# Pair-Plot Liquidity Ratios
sns.pairplot(data=liquidity_ratios_df)
plt.show()

# %%
# Heatmap for Liquidity Ratios
plt.figure(figsize=(4,4))
sns.heatmap(liquidity_ratios_df.corr(), annot=True)
plt.show()

# %%
# Heatmap for Solvency Ratios
plt.figure(figsize=(5,5))
sns.heatmap(solvency_ratios_df.corr(), annot=True)
plt.show()

# %%
# Heatmap for Activity Ratios
plt.figure(figsize=(5,5))
sns.heatmap(activity_ratios_df.corr(), annot=True)
plt.show()

# %%
# Heatmap for Profitability Ratios
plt.figure(figsize=(5,5))
sns.heatmap(profit_ratios_df.corr(), annot=True)
plt.show()

# %%
# Select some colums
raw_num_df = raw_df[[
       'total_assets', 'total_liabilities',
       'total_debt', 'total_equity', 'gross_profit',
       'operating_income',  
       'total_revenue', 'net_income', 
       # 'total_current_liab', 'basic_earning_power',
       # 'debt_ratio', 'debt_to_equity',
       # 'equity_ratio', 'gross_profit_margin', 'net_inc_margin', 'quick_ratio',
       ]]

# %%
sns.pairplot(data=raw_num_df)
plt.show()

# %%
raw_num_df.corr()
# Out:
#                    total_assets  total_liabilities  total_debt  total_equity  \
# total_assets           1.000000           0.992557    0.850824      0.680886
# total_liabilities      0.992557           1.000000    0.852294      0.586625
# total_debt             0.850824           0.852294    1.000000      0.532388
# total_equity           0.680886           0.586625    0.532388      1.000000
# gross_profit          -0.044844          -0.046093   -0.048623     -0.024156
# operating_income      -0.011573          -0.009431   -0.015784     -0.021456
# total_revenue         -0.044067          -0.044428   -0.054000     -0.025875
# net_income            -0.004134          -0.002418   -0.008617     -0.012976
#
#                    gross_profit  operating_income  total_revenue  net_income
# total_assets          -0.044844         -0.011573      -0.044067   -0.004134
# total_liabilities     -0.046093         -0.009431      -0.044428   -0.002418
# total_debt            -0.048623         -0.015784      -0.054000   -0.008617
# total_equity          -0.024156         -0.021456      -0.025875   -0.012976
# gross_profit           1.000000          0.502125       0.902815    0.308712
# operating_income       0.502125          1.000000       0.460901    0.744469
# total_revenue          0.902815          0.460901       1.000000    0.284079
# net_income             0.308712          0.744469       0.284079    1.000000

# %%
plt.figure(figsize=(7,7))
sns.heatmap(raw_num_df.corr(), annot=True)
plt.show()

# %% [markdown]
# Test of getting Stock price from Yahoo!Finance

# %%
import yfinance as yf
import pandas as pd

# Define the ticker symbol
ticker = 'AAPL' # Apple Stock

# Get data on this ticker
stock = yf.Ticker(ticker)

# Get historical market data
hist = stock.history(period="1y")

# Calculate moving averages
hist['SMA50'] = hist['Close'].rolling(window=50).mean()
hist['SMA200'] = hist['Close'].rolling(window=200).mean()

# Calculate Relative Strength Index (RSI)
def calculate_rsi(data, window=14):
    delta = data.diff(1)
    gain = delta.where(delta > 0, 0)
    loss = -delta.where(delta < 0, 0)
    average_gain = gain.rolling(window=window).mean()
    average_loss = loss.rolling(window=window).mean()
    rs = average_gain / average_loss
    rsi = 100 - (100 / (1 + rs))
    return rsi

hist['RSI'] = calculate_rsi(hist['Close'])

# Get financials (simplified)
# Use the information already available in yfinance
info = stock.info

# Print key financial information
print(f"Company: {info.get('longName')}")
print(f"Market Cap: {info.get('marketCap')}")
print(f"PE Ratio (TTM): {info.get('trailingPE')}")
print(f"EPS (TTM): {info.get('trailingEps')}")
print(f"Dividend Yield: {info.get('dividendYield')}")

# Print the recent stock data with calculated indicators
print(hist.tail())
# Out:
# Company: Apple Inc.
# Market Cap: 2982175571968
# PE Ratio (TTM): 30.292833
# EPS (TTM): 6.42
# Dividend Yield: 0.0050999997
#                                  Open        High         Low       Close  \
# Date
# 2024-05-31 00:00:00-04:00  191.440002  192.570007  189.910004  192.250000
# 2024-06-03 00:00:00-04:00  192.899994  194.990005  192.520004  194.029999
# 2024-06-04 00:00:00-04:00  194.639999  195.320007  193.029999  194.350006
# 2024-06-05 00:00:00-04:00  195.399994  196.899994  194.869995  195.869995
# 2024-06-06 00:00:00-04:00  195.684998  196.500000  194.169998  194.479996
#
#                              Volume  Dividends  Stock Splits       SMA50  \
# Date
# 2024-05-31 00:00:00-04:00  75158300        0.0           0.0  177.008785
# 2024-06-03 00:00:00-04:00  50080500        0.0           0.0  177.466627
# 2024-06-04 00:00:00-04:00  47471400        0.0           0.0  177.912694
# 2024-06-05 00:00:00-04:00  54156800        0.0           0.0  178.417722
# 2024-06-06 00:00:00-04:00  40958779        0.0           0.0  178.917720
#
#                                SMA200        RSI
# Date
# 2024-05-31 00:00:00-04:00  180.798980  72.840112
# 2024-06-03 00:00:00-04:00  180.889758  70.733010
# 2024-06-04 00:00:00-04:00  180.994936  69.372921
# 2024-06-05 00:00:00-04:00  181.105273  67.992964
# 2024-06-06 00:00:00-04:00  181.201936  62.636163
