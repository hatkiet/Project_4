# %% [markdown]
# <a href="https://colab.research.google.com/github/hatkiet/Project_4/blob/Mia-branch/Heart_Attack_ML_3_MH.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Import required libraries and dependencies
import warnings
warnings.simplefilter(action='ignore')

import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import missingno as msno

from sklearn.cluster import KMeans
from sklearn.decomposition import PCA
from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import MinMaxScaler
from sklearn.preprocessing import RobustScaler, StandardScaler
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import RandomizedSearchCV
from sklearn.metrics import confusion_matrix,accuracy_score,roc_curve,classification_report

# %%
# Load the data into a Pandas DataFrame
df = pd.read_csv("heart_2022_with_nans.csv")
# Display sample data
df.head()
# Out:
#      State     Sex GeneralHealth  PhysicalHealthDays  MentalHealthDays  \
# 0  Alabama  Female     Very good                 0.0               0.0
# 1  Alabama  Female     Excellent                 0.0               0.0
# 2  Alabama  Female     Very good                 2.0               3.0
# 3  Alabama  Female     Excellent                 0.0               0.0
# 4  Alabama  Female          Fair                 2.0               0.0
#
#                                      LastCheckupTime PhysicalActivities  \
# 0  Within past year (anytime less than 12 months ...                 No
# 1                                                NaN                 No
# 2  Within past year (anytime less than 12 months ...                Yes
# 3  Within past year (anytime less than 12 months ...                Yes
# 4  Within past year (anytime less than 12 months ...                Yes
#
#    SleepHours RemovedTeeth HadHeartAttack  ... HeightInMeters  \
# 0         8.0          NaN             No  ...            NaN
# 1         6.0          NaN             No  ...           1.60
# 2         5.0          NaN             No  ...           1.57
# 3         7.0          NaN             No  ...           1.65
# 4         9.0          NaN             No  ...           1.57
#
#   WeightInKilograms    BMI AlcoholDrinkers HIVTesting FluVaxLast12  \
# 0               NaN    NaN              No         No          Yes
# 1             68.04  26.57              No         No           No
# 2             63.50  25.61              No         No           No
# 3             63.50  23.30              No         No          Yes
# 4             53.98  21.77             Yes         No           No
#
#   PneumoVaxEver                                  TetanusLast10Tdap  \
# 0            No  Yes, received tetanus shot but not sure what type
# 1            No  No, did not receive any tetanus shot in the pa...
# 2            No                                                NaN
# 3           Yes  No, did not receive any tetanus shot in the pa...
# 4           Yes  No, did not receive any tetanus shot in the pa...
#
#   HighRiskLastYear CovidPos
# 0               No       No
# 1               No       No
# 2               No      Yes
# 3               No       No
# 4               No       No
#
# [5 rows x 40 columns]

# %%
# Find the duplicated values
df.duplicated().sum()

# Drop duplicated values
df.drop_duplicates(inplace=True)

# Check again information of dataset
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 87517 entries, 0 to 87551
# Data columns (total 40 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   State                      87517 non-null  object
#  1   Sex                        87517 non-null  object
#  2   GeneralHealth              87255 non-null  object
#  3   PhysicalHealthDays         85065 non-null  float64
#  4   MentalHealthDays           85469 non-null  float64
#  5   LastCheckupTime            85842 non-null  object
#  6   PhysicalActivities         87286 non-null  object
#  7   SleepHours                 86410 non-null  float64
#  8   RemovedTeeth               84112 non-null  object
#  9   HadHeartAttack             86800 non-null  object
#  10  HadAngina                  86577 non-null  object
#  11  HadStroke                  87162 non-null  object
#  12  HadAsthma                  87127 non-null  object
#  13  HadSkinCancer              86807 non-null  object
#  14  HadCOPD                    87041 non-null  object
#  15  HadDepressiveDisorder      86912 non-null  object
#  16  HadKidneyDisease           87107 non-null  object
#  17  HadArthritis               86988 non-null  object
#  18  HadDiabetes                87246 non-null  object
#  19  DeafOrHardOfHearing        82674 non-null  object
#  20  BlindOrVisionDifficulty    82417 non-null  object
#  21  DifficultyConcentrating    81842 non-null  object
#  22  DifficultyWalking          81767 non-null  object
#  23  DifficultyDressingBathing  81782 non-null  object
#  24  DifficultyErrands          81412 non-null  object
#  25  SmokerStatus               79115 non-null  object
#  26  ECigaretteUsage            78993 non-null  object
#  27  ChestScan                  75039 non-null  object
#  28  RaceEthnicityCategory      84334 non-null  object
#  29  AgeCategory                85496 non-null  object
#  30  HeightInMeters             80957 non-null  float64
#  31  WeightInKilograms          78813 non-null  float64
#  32  BMI                        77285 non-null  float64
#  33  AlcoholDrinkers            76739 non-null  object
#  34  HIVTesting                 72737 non-null  object
#  35  FluVaxLast12               76514 non-null  object
#  36  PneumoVaxEver              70578 non-null  object
#  37  TetanusLast10Tdap          69583 non-null  object
#  38  HighRiskLastYear           75631 non-null  object
#  39  CovidPos                   75516 non-null  object
# dtypes: float64(6), object(34)
# memory usage: 27.4+ MB

# %%
# Finding NAN values
nan_values = df.isna().sum().sort_values(ascending=False)
nan_values_percentage = (nan_values/df.shape[0])*100

# Output the DataFrame with two columns nan_values and nan_values_percentage
pd.concat([nan_values, nan_values_percentage], axis=1).rename(columns= {0:"NaN Values", 1:"(%) of NaN Values"}).round(2)
# Out:
#                            NaN Values  (%) of NaN Values
# TetanusLast10Tdap               17934              20.49
# PneumoVaxEver                   16939              19.36
# HIVTesting                      14780              16.89
# ChestScan                       12478              14.26
# CovidPos                        12001              13.71
# HighRiskLastYear                11886              13.58
# FluVaxLast12                    11003              12.57
# AlcoholDrinkers                 10778              12.32
# BMI                             10232              11.69
# WeightInKilograms                8704               9.95
# ECigaretteUsage                  8524               9.74
# SmokerStatus                     8402               9.60
# HeightInMeters                   6560               7.50
# DifficultyErrands                6105               6.98
# DifficultyWalking                5750               6.57
# DifficultyDressingBathing        5735               6.55
# DifficultyConcentrating          5675               6.48
# BlindOrVisionDifficulty          5100               5.83
# DeafOrHardOfHearing              4843               5.53
# RemovedTeeth                     3405               3.89
# RaceEthnicityCategory            3183               3.64
# PhysicalHealthDays               2452               2.80
# MentalHealthDays                 2048               2.34
# AgeCategory                      2021               2.31
# LastCheckupTime                  1675               1.91
# SleepHours                       1107               1.26
# HadAngina                         940               1.07
# HadHeartAttack                    717               0.82
# HadSkinCancer                     710               0.81
# HadDepressiveDisorder             605               0.69
# HadArthritis                      529               0.60
# HadCOPD                           476               0.54
# HadKidneyDisease                  410               0.47
# HadAsthma                         390               0.45
# HadStroke                         355               0.41
# HadDiabetes                       271               0.31
# GeneralHealth                     262               0.30
# PhysicalActivities                231               0.26
# Sex                                 0               0.00
# State                               0               0.00

# %%
# Renaming columns using a dictionary
df1 = df.rename(columns={
    'AgeCategory': "Age",
    'RaceEthnicityCategory': "Race",
    'GeneralHealth': "GenHealth",
    'PhysicalHealthDays': "PhysicalHealth",
    'PhysicalActivities': "PhysicalActivity",
    'MentalHealthDays': "MentalHealth",
    'HadAngina': "Angina",
    'HadHeartAttack': "HeartAttack",
    'HadStroke': "Stroke",
    'HadAsthma': "Asthma",
    'HadSkinCancer': "SkinCancer",
    'HadDepressiveDisorder': "Depressed",
    'HadKidneyDisease': "KidneyDisease",
    'DifficultyWalking': "DiffWalking",
    'HadDiabetes': "Diabetes",
    'SmokerStatus': "Smoking",
    'AlcoholDrinkers': "Drinking"
})
df1
# Out:
#          State     Sex  GenHealth  PhysicalHealth  MentalHealth  \
# 0      Alabama  Female  Very good             0.0           0.0
# 1      Alabama  Female  Excellent             0.0           0.0
# 2      Alabama  Female  Very good             2.0           3.0
# 3      Alabama  Female  Excellent             0.0           0.0
# 4      Alabama  Female       Fair             2.0           0.0
# ...        ...     ...        ...             ...           ...
# 87547   Hawaii    Male       Good             0.0           7.0
# 87548   Hawaii    Male  Very good             1.0           5.0
# 87549   Hawaii    Male       Fair             0.0           0.0
# 87550   Hawaii    Male       Good             0.0           0.0
# 87551   Hawaii    Male  Excellent             0.0           0.0
#
#                                          LastCheckupTime PhysicalActivity  \
# 0      Within past year (anytime less than 12 months ...               No
# 1                                                    NaN               No
# 2      Within past year (anytime less than 12 months ...              Yes
# 3      Within past year (anytime less than 12 months ...              Yes
# 4      Within past year (anytime less than 12 months ...              Yes
# ...                                                  ...              ...
# 87547  Within past year (anytime less than 12 months ...              Yes
# 87548  Within past year (anytime less than 12 months ...              Yes
# 87549  Within past year (anytime less than 12 months ...              Yes
# 87550  Within past year (anytime less than 12 months ...              Yes
# 87551  Within past 5 years (2 years but less than 5 y...              Yes
#
#        SleepHours  RemovedTeeth HeartAttack  ... HeightInMeters  \
# 0             8.0           NaN          No  ...            NaN
# 1             6.0           NaN          No  ...           1.60
# 2             5.0           NaN          No  ...           1.57
# 3             7.0           NaN          No  ...           1.65
# 4             9.0           NaN          No  ...           1.57
# ...           ...           ...         ...  ...            ...
# 87547         7.0  None of them          No  ...           1.75
# 87548         6.0  None of them          No  ...           1.91
# 87549         6.0  None of them          No  ...           1.75
# 87550         6.0  None of them          No  ...           1.70
# 87551         5.0        1 to 5          No  ...            NaN
#
#       WeightInKilograms    BMI Drinking HIVTesting FluVaxLast12 PneumoVaxEver  \
# 0                   NaN    NaN       No         No          Yes            No
# 1                 68.04  26.57       No         No           No            No
# 2                 63.50  25.61       No         No           No            No
# 3                 63.50  23.30       No         No          Yes           Yes
# 4                 53.98  21.77      Yes         No           No           Yes
# ...                 ...    ...      ...        ...          ...           ...
# 87547             72.57  23.63       No        NaN          Yes           NaN
# 87548             95.25  26.25       No        Yes          Yes            No
# 87549            117.93  38.39      Yes        NaN           No            No
# 87550             79.38  27.41      Yes        Yes          Yes            No
# 87551               NaN    NaN      NaN        NaN          NaN           NaN
#
#                                        TetanusLast10Tdap HighRiskLastYear  \
# 0      Yes, received tetanus shot but not sure what type               No
# 1      No, did not receive any tetanus shot in the pa...               No
# 2                                                    NaN               No
# 3      No, did not receive any tetanus shot in the pa...               No
# 4      No, did not receive any tetanus shot in the pa...               No
# ...                                                  ...              ...
# 87547                                                NaN              NaN
# 87548                                 Yes, received Tdap              Yes
# 87549                                                NaN               No
# 87550                                 Yes, received Tdap               No
# 87551                                                NaN              NaN
#
#       CovidPos
# 0           No
# 1           No
# 2          Yes
# 3           No
# 4           No
# ...        ...
# 87547      NaN
# 87548       No
# 87549      Yes
# 87550       No
# 87551      NaN
#
# [87517 rows x 40 columns]

# %%
# Remove the missing values
df1 = df1.dropna()

# Check again the missing values
df1.isna().sum()
# Out:
# State                        0
# Sex                          0
# GenHealth                    0
# PhysicalHealth               0
# MentalHealth                 0
# LastCheckupTime              0
# PhysicalActivity             0
# SleepHours                   0
# RemovedTeeth                 0
# HeartAttack                  0
# Angina                       0
# Stroke                       0
# Asthma                       0
# SkinCancer                   0
# HadCOPD                      0
# Depressed                    0
# KidneyDisease                0
# HadArthritis                 0
# Diabetes                     0
# DeafOrHardOfHearing          0
# BlindOrVisionDifficulty      0
# DifficultyConcentrating      0
# DiffWalking                  0
# DifficultyDressingBathing    0
# DifficultyErrands            0
# Smoking                      0
# ECigaretteUsage              0
# ChestScan                    0
# Race                         0
# Age                          0
# HeightInMeters               0
# WeightInKilograms            0
# BMI                          0
# Drinking                     0
# HIVTesting                   0
# FluVaxLast12                 0
# PneumoVaxEver                0
# TetanusLast10Tdap            0
# HighRiskLastYear             0
# CovidPos                     0
# dtype: int64
